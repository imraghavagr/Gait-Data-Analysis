# %%
import dtale
import pandas as pd

# %%
df = pd.read_csv('data1.csv')

# %%
df.head()
# Out:
#    id          y        t      x1      x2      x3       x4       x5      x6  \
# 0   1  walkontoe  44:19.9  0.2129 -0.7217  1.6621  10.9253  23.0713 -8.6670
# 1   1  walkontoe  44:19.9  0.2188 -0.6841  1.7085   8.5449  24.7803 -6.6528
# 2   1  walkontoe  44:19.9  0.2300 -0.6777  1.7251   0.1831  24.2310 -6.4697
# 3   1  walkontoe  44:19.9  0.2358 -0.7075  1.6978  -9.2773  21.4844 -6.8359
# 4   1  walkontoe  44:19.9  0.2378 -0.7476  1.6519 -12.8784  19.2261 -6.8359
#
#         x7      x8      x9      x10
# 0 -34.5081 -8.3386 -1.0931  33.8534
# 1 -34.3927 -8.1683 -1.2854  33.8564
# 2 -34.3652 -8.0035 -1.4777  33.8652
# 3 -34.4312 -7.8662 -1.6589  33.8564
# 4 -34.5355 -7.7454 -1.8237  33.8534

# %%
df.drop(['id','t'], axis=1, inplace=True)

# %%
df.head()
# Out:
#            y      x1      x2      x3       x4       x5      x6       x7  \
# 0  walkontoe  0.2129 -0.7217  1.6621  10.9253  23.0713 -8.6670 -34.5081
# 1  walkontoe  0.2188 -0.6841  1.7085   8.5449  24.7803 -6.6528 -34.3927
# 2  walkontoe  0.2300 -0.6777  1.7251   0.1831  24.2310 -6.4697 -34.3652
# 3  walkontoe  0.2358 -0.7075  1.6978  -9.2773  21.4844 -6.8359 -34.4312
# 4  walkontoe  0.2378 -0.7476  1.6519 -12.8784  19.2261 -6.8359 -34.5355
#
#        x8      x9      x10
# 0 -8.3386 -1.0931  33.8534
# 1 -8.1683 -1.2854  33.8564
# 2 -8.0035 -1.4777  33.8652
# 3 -7.8662 -1.6589  33.8564
# 4 -7.7454 -1.8237  33.8534

# %%
# dtale.show(df)
